# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 腐蚀操作
# - 通常腐蚀操作都对binary图像操作
# - 原理是如果kernal范围里既有黑又有白，则把这块区域都涂黑

# %%
img= cv2.imread('dige.png', cv2.IMREAD_GRAYSCALE)
print(img.shape)

plt.imshow(img, cmap='gray')
# Out:
# (354, 503)

# %%
kernal = np.ones((3, 3), np.uint8)
img_erosion= cv2.erode(img, kernal, iterations=1)

plt.imshow(img_erosion, cmap='gray')

# %% [markdown]
# ### 膨胀操作
# - 原理是如果kernal范围里既有黑又有白，则把这块区域都涂白

# %%
kernel = np.ones((3, 3), np.uint8)
img_dilation = cv2.dilate(img_erosion, kernel, iterations=1)

plt.imshow(img_dilation, cmap='gray')

# %% [markdown]
# ### 开运算与闭运算
# - 开运算 最后是膨胀
# - 闭运算 最后是闭合

# %%
img= cv2.imread('dige.png', cv2.IMREAD_GRAYSCALE)

kernal = np.ones((5, 5), np.uint8)
opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernal)

plt.imshow(opening, cmap='gray')

# %%
img= cv2.imread('dige.png', cv2.IMREAD_GRAYSCALE)

kernal = np.ones((5, 5), np.uint8)
closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernal)

plt.imshow(closing, cmap='gray')

# %% [markdown]
# ### 梯度运算
# - 梯度= 膨胀-腐蚀

# %%
gradient = cv2.morphologyEx(img, cv2.MORPH_GRADIENT, kernal)

cv2.imshow('Gradient', gradient)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ### 礼帽与黑帽
# - 礼帽(留下刺)= 原始输入-开运算结果
# - 黑帽(留下一个轮廓)= 闭运算-原始输入

# %%
tophat= cv2.morphologyEx(img, cv2.MORPH_TOPHAT, kernal)
plt.imshow(tophat, cmap='gray')

# %%
blackhat= cv2.morphologyEx(img, cv2.MORPH_BLACKHAT, kernal)
plt.imshow(blackhat, cmap='gray')
